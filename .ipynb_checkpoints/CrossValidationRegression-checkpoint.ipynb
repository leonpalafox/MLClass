# %% [markdown]
# # Cross validation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = '\data\adult.csv'
data = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-091d68fbd118> in <module>()
#       4
#       5 path = '\data\adult.csv'
# ----> 6 data = pd.read_csv(path)
#
# ...

# %%
data.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-66a0473f7c22> in <module>()
# ----> 1 data.plot()
#
# NameError: name 'data' is not defined
