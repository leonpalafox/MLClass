# %%
import pylab as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
# %matplotlib inline

# %%
mean = [0, 0]
cov = [[1,0],[0,1]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
# Out:
# (-5.0, 5.0, -4.0, 4.0)

# %%
mean = [0, 0]
cov = [[1,0.5],[0.5,1]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
# Out:
# (-4.0, 4.0, -5.0, 5.0)

# %% [markdown]
# # Analyzing the primary results of 2016

# %%
primary_results = pd.read_csv( 'data/primary_results.csv' )
county_facts = pd.read_csv( 'data/county_facts.csv' )
county_facts_dict = pd.read_csv( 'data/county_facts_dictionary.csv' )
dict_county_facts = {k: v for k, v in zip(county_facts_dict['column_name'].values, county_facts_dict['description'].values)}

# %%
county_facts_results.head()
# Out:
#               area_name state_abbreviation  PST045214  PST040210  PST120214  \
# fips
# NaN                 NaN                NaN        NaN        NaN        NaN
# NaN                 NaN                NaN        NaN        NaN        NaN
# NaN                 NaN                NaN        NaN        NaN        NaN
#  1001.0  Autauga County                 AL    55395.0    54571.0        1.5
#  1003.0  Baldwin County                 AL   200111.0   182265.0        9.8
#
#          POP010210  AGE135214  AGE295214  AGE775214  SEX255214    ...      \
# fips                                                              ...
# NaN            NaN        NaN        NaN        NaN        NaN    ...
# NaN            NaN        NaN        NaN        NaN        NaN    ...
# NaN            NaN        NaN        NaN        NaN        NaN    ...
#  1001.0    54571.0        6.0       25.2       13.8       51.4    ...
#  1003.0   182265.0        5.6       22.2       18.7       51.2    ...
#
#          SBO415207  SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  \
# fips
# NaN            NaN        NaN        NaN        NaN        NaN        NaN
# NaN            NaN        NaN        NaN        NaN        NaN        NaN
# NaN            NaN        NaN        NaN        NaN        NaN        NaN
#  1001.0        0.7       31.7        0.0        0.0   598175.0    12003.0
#  1003.0        1.3       27.3  1410273.0        0.0  2966489.0    17166.0
#
#          AFN120207  BPS030214  LND110210  POP060210
# fips
# NaN            NaN        NaN        NaN        NaN
# NaN            NaN        NaN        NaN        NaN
# NaN            NaN        NaN        NaN        NaN
#  1001.0    88157.0      131.0     594.44       91.8
#  1003.0   436955.0     1384.0    1589.78      114.6
#
# [5 rows x 53 columns]

# %%
trump_results = primary_results[ primary_results[ 'candidate' ] == 'Donald Trump' ]

# %%
trump_results.head()
# Out:
#        state state_abbreviation   county    fips       party     candidate  \
# 135  Alabama                 AL  Autauga  1001.0  Republican  Donald Trump
# 140  Alabama                 AL  Baldwin  1003.0  Republican  Donald Trump
# 145  Alabama                 AL  Barbour  1005.0  Republican  Donald Trump
# 150  Alabama                 AL     Bibb  1007.0  Republican  Donald Trump
# 155  Alabama                 AL   Blount  1009.0  Republican  Donald Trump
#
#      votes  fraction_votes
# 135   5387           0.445
# 140  23618           0.469
# 145   1710           0.501
# 150   1959           0.494
# 155   7390           0.487

# %%
county_facts.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# 0       28.8  5319456312  4174286516  3917663456      12990  613795732
# 1       28.1   112858843    52252752    57344851      12364    6426342
# 2       31.7           0           0      598175      12003      88157
# 3       27.3     1410273           0     2966489      17166     436955
# 4       27.0           0           0      188337       6334          0
#
#    BPS030214   LND110210  POP060210
# 0    1046363  3531905.43       87.4
# 1      13369    50645.33       94.4
# 2        131      594.44       91.8
# 3       1384     1589.78      114.6
# 4          8      884.88       31.0
#
# [5 rows x 54 columns]

# %%
df_all =trump_results.merge(county_facts, on=['fips'])

# %%
df_all.head()
# Out:
#      state state_abbreviation_x   county    fips       party     candidate  \
# 0  Alabama                   AL  Autauga  1001.0  Republican  Donald Trump
# 1  Alabama                   AL  Baldwin  1003.0  Republican  Donald Trump
# 2  Alabama                   AL  Barbour  1005.0  Republican  Donald Trump
# 3  Alabama                   AL     Bibb  1007.0  Republican  Donald Trump
# 4  Alabama                   AL   Blount  1009.0  Republican  Donald Trump
#
#    votes  fraction_votes       area_name state_abbreviation_y    ...      \
# 0   5387           0.445  Autauga County                   AL    ...
# 1  23618           0.469  Baldwin County                   AL    ...
# 2   1710           0.501  Barbour County                   AL    ...
# 3   1959           0.494     Bibb County                   AL    ...
# 4   7390           0.487   Blount County                   AL    ...
#
#    SBO415207  SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  \
# 0        0.7       31.7          0          0     598175      12003
# 1        1.3       27.3    1410273          0    2966489      17166
# 2        0.0       27.0          0          0     188337       6334
# 3        0.0        0.0          0          0     124707       5804
# 4        0.0       23.2     341544          0     319700       5622
#
#    AFN120207  BPS030214  LND110210  POP060210
# 0      88157        131     594.44       91.8
# 1     436955       1384    1589.78      114.6
# 2          0          8     884.88       31.0
# 3      10757         19     622.58       36.8
# 4      20941          3     644.78       88.9
#
# [5 rows x 61 columns]

# %%
df_work = df_all[['EDU635213', 'EDU685213','MAN450207', 'RHI125214']]
#high_school, bachelor, manufacturing shippments, percentage of whites

# %%
data = df_work.values

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, whiten = True)
pca.fit(data)
# Out:
# PCA(copy=True, n_components=2, whiten=True)

# %%
pca_data = pca.transform(data)

# %%
pca_data.shape
# Out:
# (2711L, 2L)

# %%
pca.components_
# Out:
# array([[ -8.58341876e-08,  -3.68264066e-07,  -1.00000000e+00,
#           3.02407728e-07],
#        [ -1.42723450e-01,  -2.39662266e-02,  -2.78147650e-07,
#          -9.89472403e-01]])

# %%
plt.scatter(pca_data[:,0],pca_data[:,1])

# %%
pca.explained_variance_ratio_
# Out:
# array([  1.00000000e+00,   7.81870621e-12])
